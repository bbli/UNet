# %%
import skimage
from skimage import io
from skimage import img_as_float
from skdemo import *
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
plt.plot([1,2,4])

# %%
#pic=img_as_float(io.imread('/data/bbli/gryllus_disk_images/cmp_1_1_T0000.tif'))
pic = io.imread('/data/bbli/gryllus_disk_images/cmp_1_1_T0000.tif')

# %%
pic.shape
# Out:
# (2001, 2001)

# %%
plt.figure(figsize=(10,10))
io.imshow(pic,cmap='gray')
# Out:
# /home/bbli/software/miniconda3/envs/fastai/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/bbli/software/miniconda3/envs/fastai/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "

# %%
imshow_with_histogram(pic)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f554ecd5748>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f554ec42358>)

# %%
pic.shape
# Out:
# (2001, 2001)

# %%
pic[0,:]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint16)

# %%
np.max(pic)
# Out:
# 267

# %% [markdown]
# * Huh, should definitively normalize the data, as everything is very close to 0

# %%
from torch.utils.data import Dataset

# %%
from skimage.transform import rescale, resize, downscale_local_mean

# %%
plt.figure(figsize=(10,10))
down_pic = downscale_local_mean(pic,(4,4))
io.imshow(down_pic,cmap='gray')
# Out:
# /home/bbli/software/miniconda3/envs/fastai/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/bbli/software/miniconda3/envs/fastai/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:77: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   warn("Float image out of standard range; displaying "

# %%
down_pic.shape
# Out:
# (501, 501)

# %%
np.max(pic)
# Out:
# 267
